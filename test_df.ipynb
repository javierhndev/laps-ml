# %%
import pandas as pd
import numpy as np

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
df_test=pd.DataFrame(exam_data,index=labels)

# %%
df_test
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      10 non-null     object
#  1   score     8 non-null      float64
#  2   attempts  10 non-null     int64
#  3   qualify   10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %%
df_test[['name','score']]
# Out:
#         name  score
# a  Anastasia   12.5
# b       Dima    9.0
# c  Katherine   16.5
# d      James    NaN
# e      Emily    9.0
# f    Michael   20.0
# g    Matthew   14.5
# h      Laura    NaN
# i      Kevin    8.0
# j      Jonas   19.0

# %%
df_test[['name','score']].iloc[[1,3,5,6]]
# Out:
#       name  score
# b     Dima    9.0
# d    James    NaN
# f  Michael   20.0
# g  Matthew   14.5

# %%
df_test[df_test['attempts']>2]
# Out:
#       name  score  attempts qualify
# b     Dima    9.0         3      no
# d    James    NaN         3      no
# f  Michael   20.0         3     yes

# %%
len(df_test.columns)
# Out:
# 4

# %%
df_test[df_test['score'].isna()]
# Out:
#     name  score  attempts qualify
# d  James    NaN         3      no
# h  Laura    NaN         1      no

# %%
df_test[(df_test['score']>15) & (df_test['score']<=20)]
# Out:
#         name  score  attempts qualify
# c  Katherine   16.5         2     yes
# f    Michael   20.0         3     yes
# j      Jonas   19.0         1     yes

# %%
#Write a Pandas program to change the score in row 'd' to 11.5
df_test['score'].loc['d']=11.5
# Out:
# /tmp/ipykernel_150252/565980620.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['score'].loc['d']=11.5

# %%
df_test.loc['k']=[ 'Suresh',15.5, 1,'yes']

# %%
df_test.drop('k')
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df_test.sort_values(by='name',ascending=False)
# Out:
#         name  score  attempts qualify
# k     Suresh   15.5         1     yes
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# c  Katherine   16.5         2     yes
# j      Jonas   19.0         1     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# b       Dima    9.0         3      no
# a  Anastasia   12.5         1     yes

# %% [raw]
# df_test['qualify'][df_test['qualify']=='yes']=True
# df_test['qualify'][df_test['qualify']=='no']=False

# %%
df_test.loc['d','name']='Suresh'

# %%
df_test
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d     Suresh    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df_test['color']=['red','red','blue','green','yellow','red','green','yellow','red','blue']

# %%
df_test
# Out:
#         name  score  attempts qualify   color
# a  Anastasia   12.5         1     yes     red
# b       Dima    9.0         3      no     red
# c  Katherine   16.5         2     yes    blue
# d     Suresh    NaN         3      no   green
# e      Emily    9.0         2      no  yellow
# f    Michael   20.0         3     yes     red
# g    Matthew   14.5         1     yes   green
# h      Laura    NaN         1      no  yellow
# i      Kevin    8.0         2      no     red
# j      Jonas   19.0         1     yes    blue

# %%
df_test.columns.values=('a','b','c','d','e')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[143], line 1
# ----> 1 df_test.columns.values=('a','b','c','d','e')
#
# AttributeError: can't set attribute 'values'

# %%
for index,row in df_test[['name','score']].iterrows():
    print(row['name'],row['score'])
# Out:
# Anastasia 12.5
# Dima 9.0
# Katherine 16.5
# James nan
# Emily 9.0
# Michael 20.0
# Matthew 14.5
# Laura nan
# Kevin 8.0
# Jonas 19.0

# %%
list(df_test.columns.values)
# Out:
# ['name', 'score', 'attempts', 'qualify']

# %%
df_test.rename(columns={'Name':'name'})
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df_test[df_test['attempts']==2]
# Out:
#         name  score  attempts qualify
# c  Katherine   16.5         2     yes
# e      Emily    9.0         2      no
# i      Kevin    8.0         2      no

# %%
df_test[['score','name']]
# Out:
#    score       name
# a   12.5  Anastasia
# b    9.0       Dima
# c   16.5  Katherine
# d    NaN      James
# e    9.0      Emily
# f   20.0    Michael
# g   14.5    Matthew
# h    NaN      Laura
# i    8.0      Kevin
# j   19.0      Jonas

# %%
df_geek = pd.read_csv('https://media.geeksforgeeks.org/wp-content/uploads/nba.csv')

# %%
grouping=df_geek.groupby(['Team','Position'])

# %%
print(grouping.size())
# Out:
# Team                Position
# Atlanta Hawks       C           3
#                     PF          4
#                     PG          2
#                     SF          2
#                     SG          4
#                                ..
# Washington Wizards  C           3
#                     PF          2
#                     PG          2
#                     SF          4
#                     SG          4
# Length: 149, dtype: int64

# %%
df_geek[(df_geek['Team']=='Atlanta Hawks') & (df_geek['Position']=='PF')]
# Out:
#                Name           Team  Number Position   Age Height  Weight  \
# 313  Kris Humphries  Atlanta Hawks    43.0       PF  31.0    6-9   235.0
# 315    Paul Millsap  Atlanta Hawks     4.0       PF  31.0    6-8   246.0
# 316    Mike Muscala  Atlanta Hawks    31.0       PF  24.0   6-11   240.0
# 319      Mike Scott  Atlanta Hawks    32.0       PF  27.0    6-8   237.0
#
#             College      Salary
# 313       Minnesota   1000000.0
# 315  Louisiana Tech  18671659.0
# 316        Bucknell    947276.0
# 319        Virginia   3333333.0

# %%
print(grouping['Weight'].mean())
# Out:
# Team                Position
# Atlanta Hawks       C           250.00
#                     PF          239.50
#                     PG          179.00
#                     SF          210.50
#                     SG          208.00
#                                  ...
# Washington Wizards  C           244.00
#                     PF          247.50
#                     PG          192.50
#                     SF          208.25
#                     SG          210.00
# Name: Weight, Length: 149, dtype: float64

# %%
df = pd.DataFrame([[4, 9]] * 3, columns=['A', 'B'])

# %%
df
# Out:
#    A  B
# 0  4  9
# 1  4  9
# 2  4  9

# %%
df['sqrtA']=df['A'].apply(np.sqrt)

# %%
df
# Out:
#    A  B  sqrtA
# 0  4  9    2.0
# 1  4  9    2.0
# 2  4  9    2.0
